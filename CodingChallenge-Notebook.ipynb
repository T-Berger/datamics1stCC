# %% [markdown]
# ### CodingChallenge Notebook

# %% [markdown]
# Lese die Datei mit einen als Textstring ein:

# %%
def read_file(filepath):
    
    with open(filepath) as f:
        str_text = f.read()
    
    return str_text

# %%
read_file('./merkel-beim-50-jahrestreffen-des-weltwirtschaftsforums-am-23-januar-2020-in-davos.txt')
# Out:
# 'Meine Damen und Herren,\nvor allem aber sehr geehrter Herr Prof. Schwab,\n\nSie haben gesagt, dass ich das zwÃ¶lfte Mal hier bin. Sie haben das 50. Mal das VergnÃ¼gen, bei diesem Ereignis zu sein â€“ und dann auch nicht nur fÃ¼r einen Tag â€“, es vorzubereiten und Menschen zusammenzubringen. Dazu mÃ¶chte ich Ihnen von ganzem Herzen gratulieren. Das ist etwas Einzigartiges, das hier in den Schweizer Bergen geschaffen wurde.\n\nDas Forum hat sich ja selbst das ehrgeizige Ziel gesetzt, den Zustand der Welt zu verbessern, und hat dazu immer wieder Vertreter von Politik, Wirtschaft und Gesellschaft zusammengebracht â€“ nicht nur in Davos, sondern auch an vielen anderen Stellen der Welt. Ich glaube, man kann feststellen, wenn wir unseren Blick einmal fÃ¼nf Jahrzehnte zurÃ¼ckschweifen lassen, dass die Welt in der Tat auch besser geworden ist.\n\nWir waren vor 50 Jahren mitten im Kalten Krieg. Deutschland war geteilt. FÃ¼r mich war es nicht absehbar, dass ich einmal hier stehen wÃ¼rde. Inzw
# ...
